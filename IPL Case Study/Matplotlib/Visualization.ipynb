# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("whitegrid")

runs_match = pd.read_csv("output/runs_per_match.csv")
team_runs = pd.read_csv("output/team_runs_per_match.csv")
top_batters = pd.read_csv("output/top_10_batters.csv")
strike = pd.read_csv("output/strike_rate.csv")
economy = pd.read_csv("output/top_10_bowlers_economy.csv")
consistent = pd.read_csv("output/consistent_batters.csv")
highest = pd.read_csv("output/highest_individual_score.csv")
boundary = pd.read_csv("output/boundary_analysis.csv")
boundary_pct = pd.read_csv("output/boundary_percentage.csv")
dot = pd.read_csv("output/dot_ball_analysis.csv")
runs_over = pd.read_csv("output/runs_per_over.csv")
powerplay = pd.read_csv("output/powerplay_performance.csv")
death = pd.read_csv("output/death_overs_performance.csv")
inning = pd.read_csv("output/run_distribution_inning.csv")
toss = pd.read_csv("output/toss_impact.csv")
pom = pd.read_csv("output/player_of_match_contribution.csv")
venue = pd.read_csv("output/venue_analysis.csv")
city = pd.read_csv("output/city_trends.csv")
season = pd.read_csv("output/season_trends.csv")
winning = pd.read_csv("output/winning_team_analysis.csv")

# %%
plt.figure(figsize=(12, 6))
sns.histplot(runs_match["total_runs"], bins=20)
plt.title("Distribution of Total Runs per Match")
plt.tight_layout()
plt.savefig("output/viz_runs_distribution.png")
plt.close()
